# %%
import pandas as pd
import os

# Chemins
csv_path = r'E:\wealth_predict\data\processed_csv\df_final_afrique_pharmacies_schools_combined_sampled_class_optimal_avec_outliers_400k_obs.csv'

images_path = r'E:\wealth_predict\data\downloaded\Image_satellite_Divers_Pays_Afrique_Zoom_18_avec_outliers'

# Charger le DataFrame
data = pd.read_csv(csv_path)

# Fonction pour générer le nom de l'image
def get_image_name(row):
    latitude = row['latitude']
    longitude = row['longitude']
    # Format du nom de l'image
    image_name = f"lat_{latitude}_lon_{longitude}_zoom_18.jpeg"
    # Vérifier si l'image existe
    image_path = os.path.join(images_path, image_name)
    return image_name if os.path.exists(image_path) else None

# Ajouter la colonne 'Image_Name'
data['Image_Name'] = data.apply(get_image_name, axis=1)

# Réorganiser les colonnes
data = data[['Image_Name', 'latitude', 'longitude', 'radiance', 'class']]

# Sauvegarder le nouveau DataFrame
output_path = r'E:\wealth_predict\data\processed_csv\df_final_avec_outliers_400k_obs_with_images.csv'

data.to_csv(output_path, index=False)

print(f"Nouveau fichier sauvegardé à : {output_path}")
# Out:
# Nouveau fichier sauvegardé à : E:\wealth_predict\data\processed_csv\df_final_avec_outliers_400k_obs_with_images.csv

# %%
data
# Out:
#                                                Image_Name   latitude  \
# 0       lat_6.331901_lon_-10.794163589081736_zoom_18.jpeg   6.331901
# 1       lat_6.175343576420597_lon_1.1992250532875222_z...   6.175344
# 2       lat_12.6794415764206_lon_-7.95747576476006_zoo...  12.679442
# 3       lat_-1.3115748235794025_lon_36.77360317685172_...  -1.311575
# 4       lat_7.695587352841195_lon_-5.041272097158268_z...   7.695587
# ...                                                   ...        ...
# 399995  lat_6.423581547158805_lon_7.498332067279639_zo...   6.423582
# 399996  lat_7.972841276420597_lon_-11.746452932604582_...   7.972841
# 399997  lat_15.006506847158803_lon_-2.9409092817502733...  15.006507
# 399998  lat_5.019248852841195_lon_-1.6332483_zoom_18.jpeg   5.019249
# 399999  lat_0.8367497235794024_lon_32.4883908_zoom_18....   0.836750
#
#         longitude   radiance  class
# 0      -10.794164  10.416490      0
# 1        1.199225  21.833025      0
# 2       -7.957476  18.863255      0
# 3       36.773603  18.404926      0
# 4       -5.041272  16.124134      0
# ...           ...        ...    ...
# 399995   7.498332   4.454690      3
# 399996 -11.746453   1.326981      3
# 399997  -2.940909   0.951933      3
# 399998  -1.633248   2.282244      3
# 399999  32.488391   2.489079      3
#
# [400000 rows x 5 columns]

# %%
# Importation des packages
import pandas as pd
import os
import pickle

# %%
#base_path = r"D:\wealth_predict_sentinel"

# %% [markdown]
# ### Modèle 1:Couche Initiale nongelée - Fully Convolutional

# %%
# Définition des chemins 
base_path = r"D:\wealth_predict_sentinel"  
input_csv_2023 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConv_sans_augm_couche_nongelee_batch_16_base_EHCVM_2018_pour_an_2023_version_2.csv")
model_path = os.path.join(base_path, "models/fullyConv_sans_augm_couche_nongelee_batch_16_logistic_sans_pca_5-fold.pkl")
output_dir_csv = os.path.join(base_path, "Data/processed_csv")

# Chargement des données de 2023
df_2023 = pd.read_csv(input_csv_2023)

# Vérification des colonnes nécessaires
features = [f'feature_{i}' for i in range(4096)]
required_columns = features + ['hhweight', 'hhsize']

missing_columns = [col for col in required_columns if col not in df_2023.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2023 : {missing_columns}")

X_2023 = df_2023[features]

from sklearn.preprocessing import StandardScaler

# Normalisation des données avec un scaler basé sur 2023
scaler = StandardScaler()
X_2023_scaled = scaler.fit_transform(X_2023)

# Normalisation et réduction de dimension
X_2023_scaled = scaler.fit_transform(X_2023)
X_2023_sans_pca = X_2023_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2023 = logistic_model.predict(X_2023_sans_pca)
df_2023['pcexp_binaire_pred'] = y_pred_2023

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2023 = (
    (df_2023['hhweight'] * df_2023['hhsize'] * df_2023['pcexp_binaire_pred']).sum() /
    (df_2023['hhweight'] * df_2023['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2023 : {weighted_predicted_poverty_2023:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConv_sans_augm_couche_nongelee_batch_16_test_with_poverty_2023_logistic_reg.csv")
df_2023.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2023 : 43.8884%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConv_sans_augm_couche_nongelee_batch_16_test_with_poverty_2023_logistic_reg.csv

# %% [markdown]
# ### Pour 2021

# %%
# Package
import pandas as pd
import os
import pickle



# Définition des chemins
input_csv_2021 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConv_sans_augm_couche_nongelee_batch_16_base_EHCVM_2018_pour_an_2021_version_2.csv")
model_path = os.path.join(base_path, "models/fullyConv_sans_augm_couche_nongelee_batch_16_logistic_sans_pca_5-fold.pkl")
output_dir_csv = os.path.join(base_path, "Data/processed_csv")

# Chargement des données de 2021
df_2021 = pd.read_csv(input_csv_2021)

# Vérification des colonnes nécessaires
features = [f'feature_{i}' for i in range(4096)]
required_columns = features + ['hhweight', 'hhsize']

missing_columns = [col for col in required_columns if col not in df_2021.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2021 : {missing_columns}")

X_2021 = df_2021[features]

from sklearn.preprocessing import StandardScaler

# Normalisation des données avec un scaler basé sur 2021
scaler = StandardScaler()
X_2021_scaled = scaler.fit_transform(X_2021)

# Normalisation et réduction de dimension
X_2021_scaled = scaler.fit_transform(X_2021)
X_2021_sans_pca = X_2021_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2021 = logistic_model.predict(X_2021_sans_pca)
df_2021['pcexp_binaire_pred'] = y_pred_2021

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2021 = (
    (df_2021['hhweight'] * df_2021['hhsize'] * df_2021['pcexp_binaire_pred']).sum() /
    (df_2021['hhweight'] * df_2021['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2021 : {weighted_predicted_poverty_2021:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConv_sans_augm_couche_nongelee_batch_16_test_with_poverty_2021_logistic_reg.csv")
df_2021.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2021 : 41.6564%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConv_sans_augm_couche_nongelee_batch_16_test_with_poverty_2021_logistic_reg.csv

# %% [markdown]
# ### Modèle 2:Couche Initiale gelée - Fully Convolutional

# %%
import os
import pickle
import pandas as pd
from sklearn.preprocessing import StandardScaler



# Définition des chemins sur Google Drive
input_csv_2023 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConv_sans_augm_couche_gelee_batch_16_base_EHCVM_2018_pour_an_2023_version_2.csv")
model_path = os.path.join(base_path, "models/fullyConv_sans_augm_couche_gelee_batch_16_logistic_sans_pca_5-fold.pkl")
output_dir_csv = os.path.join(base_path, "Data/processed_csv")

# Chargement des données de 2023
df_2023 = pd.read_csv(input_csv_2023)

# Vérification des colonnes nécessaires
features = [f'feature_{i}' for i in range(4096)]
required_columns = features + ['hhweight', 'hhsize']

missing_columns = [col for col in required_columns if col not in df_2023.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2023 : {missing_columns}")

X_2023 = df_2023[features]

# Normalisation des données avec un scaler basé sur 2023
scaler = StandardScaler()
X_2023_scaled = scaler.fit_transform(X_2023)
X_2023_sans_pca = X_2023_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2023 = logistic_model.predict(X_2023_sans_pca)
df_2023['pcexp_binaire_pred'] = y_pred_2023

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2023 = (
    (df_2023['hhweight'] * df_2023['hhsize'] * df_2023['pcexp_binaire_pred']).sum() /
    (df_2023['hhweight'] * df_2023['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2023 : {weighted_predicted_poverty_2023:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConv_sans_augm_couche_gelee_batch_16_test_with_poverty_2023_logistic_reg.csv")
df_2023.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")

# Définition des chemins sur Google Drive pour 2021
input_csv_2021 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConv_sans_augm_couche_gelee_batch_16_base_EHCVM_2018_pour_an_2021_version_2.csv")
model_path = os.path.join(base_path, "models/fullyConv_sans_augm_couche_gelee_batch_16_logistic_sans_pca_5-fold.pkl")

# Chargement des données de 2021
df_2021 = pd.read_csv(input_csv_2021)

# Vérification des colonnes nécessaires
missing_columns = [col for col in required_columns if col not in df_2021.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2021 : {missing_columns}")

X_2021 = df_2021[features]

# Normalisation des données avec un scaler basé sur 2021
scaler = StandardScaler()
X_2021_scaled = scaler.fit_transform(X_2021)
X_2021_sans_pca = X_2021_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2021 = logistic_model.predict(X_2021_sans_pca)
df_2021['pcexp_binaire_pred'] = y_pred_2021

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2021 = (
    (df_2021['hhweight'] * df_2021['hhsize'] * df_2021['pcexp_binaire_pred']).sum() /
    (df_2021['hhweight'] * df_2021['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2021 : {weighted_predicted_poverty_2021:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConv_sans_augm_couche_gelee_batch_16_test_with_poverty_2021_logistic_reg.csv")
df_2021.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2023 : 39.4941%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConv_sans_augm_couche_gelee_batch_16_test_with_poverty_2023_logistic_reg.csv
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2021 : 38.0840%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConv_sans_augm_couche_gelee_batch_16_test_with_poverty_2021_logistic_reg.csv

# %% [markdown]
# ### Modèle 3:Couche Initiale nongelée - Fully Connected

# %%
import os
import pickle
import pandas as pd
from sklearn.preprocessing import StandardScaler



# Définition des chemins sur Google Drive
input_csv_2023 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConnected_sans_augm_couche_nongelee_batch_16_base_EHCVM_2018_pour_an_2023.csv")
model_path = os.path.join(base_path, "models/fullyConnected_sans_augm_couche_nongelee_batch_16_logistic_sans_pca_5-fold.pkl")
output_dir_csv = os.path.join(base_path, "Data/processed_csv")

# Chargement des données de 2023
df_2023 = pd.read_csv(input_csv_2023)

# Vérification des colonnes nécessaires
features = [f'feature_{i}' for i in range(4096)]
required_columns = features + ['hhweight', 'hhsize']

missing_columns = [col for col in required_columns if col not in df_2023.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2023 : {missing_columns}")

X_2023 = df_2023[features]

# Normalisation des données avec un scaler basé sur 2023
scaler = StandardScaler()
X_2023_scaled = scaler.fit_transform(X_2023)
X_2023_sans_pca = X_2023_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2023 = logistic_model.predict(X_2023_sans_pca)
df_2023['pcexp_binaire_pred'] = y_pred_2023

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2023 = (
    (df_2023['hhweight'] * df_2023['hhsize'] * df_2023['pcexp_binaire_pred']).sum() /
    (df_2023['hhweight'] * df_2023['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2023 : {weighted_predicted_poverty_2023:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConnected_sans_augm_couche_nongelee_batch_16_test_with_poverty_2023_logistic_reg.csv")
df_2023.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")

# Définition des chemins sur Google Drive pour 2021
input_csv_2021 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConnected_sans_augm_couche_nongelee_batch_16_base_EHCVM_2018_pour_an_2021.csv")
model_path = os.path.join(base_path, "models/fullyConnected_sans_augm_couche_nongelee_batch_16_logistic_sans_pca_5-fold.pkl")

# Chargement des données de 2021
df_2021 = pd.read_csv(input_csv_2021)

# Vérification des colonnes nécessaires
missing_columns = [col for col in required_columns if col not in df_2021.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2021 : {missing_columns}")

X_2021 = df_2021[features]

# Normalisation des données avec un scaler basé sur 2021
scaler = StandardScaler()
X_2021_scaled = scaler.fit_transform(X_2021)
X_2021_sans_pca = X_2021_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2021 = logistic_model.predict(X_2021_sans_pca)
df_2021['pcexp_binaire_pred'] = y_pred_2021

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2021 = (
    (df_2021['hhweight'] * df_2021['hhsize'] * df_2021['pcexp_binaire_pred']).sum() /
    (df_2021['hhweight'] * df_2021['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2021 : {weighted_predicted_poverty_2021:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConnected_sans_augm_couche_nongelee_batch_16_test_with_poverty_2021_logistic_reg.csv")
df_2021.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2023 : 42.6010%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConnected_sans_augm_couche_nongelee_batch_16_test_with_poverty_2023_logistic_reg.csv
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2021 : 40.3139%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConnected_sans_augm_couche_nongelee_batch_16_test_with_poverty_2021_logistic_reg.csv

# %% [markdown]
# ### Modèle 4:Couche Initiale gelée - Fully Connected

# %%
import os
import pickle
import pandas as pd
from sklearn.preprocessing import StandardScaler



# Définition des chemins sur Google Drive
input_csv_2023 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConnected_sans_augm_couche_gelee_batch_16_base_EHCVM_2018_pour_an_2023.csv")
model_path = os.path.join(base_path, "models/fullyConnected_sans_augm_couche_gelee_batch_16_logistic_sans_pca_5-fold.pkl")
output_dir_csv = os.path.join(base_path, "Data/processed_csv")

# Chargement des données de 2023
df_2023 = pd.read_csv(input_csv_2023)

# Vérification des colonnes nécessaires
features = [f'feature_{i}' for i in range(4096)]
required_columns = features + ['hhweight', 'hhsize']

missing_columns = [col for col in required_columns if col not in df_2023.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2023 : {missing_columns}")

X_2023 = df_2023[features]

# Normalisation des données avec un scaler basé sur 2023
scaler = StandardScaler()
X_2023_scaled = scaler.fit_transform(X_2023)
X_2023_sans_pca = X_2023_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2023 = logistic_model.predict(X_2023_sans_pca)
df_2023['pcexp_binaire_pred'] = y_pred_2023

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2023 = (
    (df_2023['hhweight'] * df_2023['hhsize'] * df_2023['pcexp_binaire_pred']).sum() /
    (df_2023['hhweight'] * df_2023['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2023 : {weighted_predicted_poverty_2023:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConnected_sans_augm_couche_gelee_batch_16_test_with_poverty_2023_logistic_reg.csv")
df_2023.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")

# Définition des chemins sur Google Drive pour 2021
input_csv_2021 = os.path.join(base_path, "Data/processed_csv/images_with_features_extracted_4096_fullyConnected_sans_augm_couche_gelee_batch_16_base_EHCVM_2018_pour_an_2021.csv")
model_path = os.path.join(base_path, "models/fullyConnected_sans_augm_couche_gelee_batch_16_logistic_sans_pca_5-fold.pkl")

# Chargement des données de 2021
df_2021 = pd.read_csv(input_csv_2021)

# Vérification des colonnes nécessaires
missing_columns = [col for col in required_columns if col not in df_2021.columns]
if missing_columns:
    raise ValueError(f"Les colonnes suivantes sont manquantes dans les données de 2021 : {missing_columns}")

X_2021 = df_2021[features]

# Normalisation des données avec un scaler basé sur 2021
scaler = StandardScaler()
X_2021_scaled = scaler.fit_transform(X_2021)
X_2021_sans_pca = X_2021_scaled

# Chargement du modèle
with open(model_path, 'rb') as file:
    logistic_model, _ = pickle.load(file)

print(type(logistic_model))

# Prédictions
y_pred_2021 = logistic_model.predict(X_2021_sans_pca)
df_2021['pcexp_binaire_pred'] = y_pred_2021

# Calcul du taux de pauvreté prévisionnel
weighted_predicted_poverty_2021 = (
    (df_2021['hhweight'] * df_2021['hhsize'] * df_2021['pcexp_binaire_pred']).sum() /
    (df_2021['hhweight'] * df_2021['hhsize']).sum()
)

print(f"Taux de pauvreté prévisionnel en 2021 : {weighted_predicted_poverty_2021:.4%}")

# Sauvegarde des résultats
final_csv_path = os.path.join(output_dir_csv, "fullyConnected_sans_augm_couche_gelee_batch_16_test_with_poverty_2021_logistic_reg.csv")
df_2021.to_csv(final_csv_path, index=False)

print(f"Les prédictions ont été sauvegardées dans : {final_csv_path}")
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2023 : 40.5476%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConnected_sans_augm_couche_gelee_batch_16_test_with_poverty_2023_logistic_reg.csv
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Taux de pauvreté prévisionnel en 2021 : 42.7575%
# Les prédictions ont été sauvegardées dans : D:\wealth_predict_sentinel\Data/processed_csv\fullyConnected_sans_augm_couche_gelee_batch_16_test_with_poverty_2021_logistic_reg.csv
